# %% [markdown]
# # **PROJECT - GLOBAL TERRORISM DATABASE -EXPLORATORY DATA ANALYSIS**

# %% [markdown]
# The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks. The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.

# %% [markdown]
# **Explore and analyze the data to discover key findings pertaining to terrorist activities.**

# %%
# Step:-1 Understand The Data

# Import Python Libraries
import pandas as pd
import numpy as np
import seaborn as sns     #Visualisation
import matplotlib.pyplot as plt  #Visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Global Terrorism Data.csv" ,encoding = 'latin1')

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df= df.rename( columns ={'iyear':'Year' , 'iday':'Day' , 'imonth': 'Month' ,'country_txt':'Country Name' , 'region_txt':'Region Name' })
print(df)
# Out:
#              eventid  Year  Month  Day approxdate  extended resolution  \
# 0       197000000001  1970      7    2        NaN         0        NaN
# 1       197000000002  1970      0    0        NaN         0        NaN
# 2       197001000001  1970      1    0        NaN         0        NaN
# 3       197001000002  1970      1    0        NaN         0        NaN
# 4       197001000003  1970      1    0        NaN         0        NaN
# ...              ...   ...    ...  ...        ...       ...        ...
# 181686  201712310022  2017     12   31        NaN         0        NaN
# 181687  201712310029  2017     12   31        NaN         0        NaN
# 181688  201712310030  2017     12   31        NaN         0        NaN
# 181689  201712310031  2017     12   31        NaN         0        NaN
# 181690  201712310032  2017     12   31        NaN         0        NaN
#
#         country        Country Name  region  ... addnotes  \
# ...

# %%
df.head()
# Out:
#         eventid  Year  Month  Day approxdate  extended resolution  country  \
# 0  197000000001  1970      7    2        NaN         0        NaN       58
# 1  197000000002  1970      0    0        NaN         0        NaN      130
# 2  197001000001  1970      1    0        NaN         0        NaN      160
# 3  197001000002  1970      1    0        NaN         0        NaN       78
# 4  197001000003  1970      1    0        NaN         0        NaN      101
#
#          Country Name  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %%
df.describe(include = 'all')
# Out:
#              eventid           Year          Month            Day  \
# count   1.816910e+05  181691.000000  181691.000000  181691.000000
# unique           NaN            NaN            NaN            NaN
# top              NaN            NaN            NaN            NaN
# freq             NaN            NaN            NaN            NaN
# mean    2.002705e+11    2002.638997       6.467277      15.505644
# std     1.325957e+09      13.259430       3.388303       8.814045
# min     1.970000e+11    1970.000000       0.000000       0.000000
# 25%     1.991021e+11    1991.000000       4.000000       8.000000
# 50%     2.009022e+11    2009.000000       6.000000      15.000000
# 75%     2.014081e+11    2014.000000       9.000000      23.000000
# max     2.017123e+11    2017.000000      12.000000      31.000000
#
#                    approxdate       extended resolution        country  \
# count                    9239  181691.000000       2220  181691.000000
# ...

# %%
x = df.isnull().sum()
print(x.to_string())
# Out:
# eventid                    0
# Year                       0
# Month                      0
# Day                        0
# approxdate            172452
# extended                   0
# resolution            179471
# country                    0
# Country Name               0
# region                     0
# Region Name                0
# provstate                421
# city                     434
# latitude                4556
# longitude               4557
# specificity                6
# vicinity                   0
# location              126196
# summary                66129
# crit1                      0
# crit2                      0
# crit3                      0
# doubtterr                  1
# alternative           152680
# alternative_txt       152680
# multiple                   1
# success                    0
# suicide                    0
# attacktype1                0
# attacktype1_txt            0
# attacktype2           175377
# attacktype2_txt       175377
# ...

# %%
df.head()
# Out:
#         eventid  Year  Month  Day approxdate  extended resolution  country  \
# 0  197000000001  1970      7    2        NaN         0        NaN       58
# 1  197000000002  1970      0    0        NaN         0        NaN      130
# 2  197001000001  1970      1    0        NaN         0        NaN      160
# 3  197001000002  1970      1    0        NaN         0        NaN       78
# 4  197001000003  1970      1    0        NaN         0        NaN      101
#
#          Country Name  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.isnull().sum()
# Out:
# eventid            0
# Year               0
# Month              0
# Day                0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
df=df.dropna(thresh=100000 , axis =1)
df
# Out:
#              eventid  Year  Month  Day  extended  country        Country Name  \
# 0       197000000001  1970      7    2         0       58  Dominican Republic
# 1       197000000002  1970      0    0         0      130              Mexico
# 2       197001000001  1970      1    0         0      160         Philippines
# 3       197001000002  1970      1    0         0       78              Greece
# 4       197001000003  1970      1    0         0      101               Japan
# ...              ...   ...    ...  ...       ...      ...                 ...
# 181686  201712310022  2017     12   31         0      182             Somalia
# 181687  201712310029  2017     12   31         0      200               Syria
# 181688  201712310030  2017     12   31         0      160         Philippines
# 181689  201712310031  2017     12   31         0       92               India
# 181690  201712310032  2017     12   31         0      160         Philippines
#
# ...

# %%
df = df.dropna(thresh=50 ,axis=0)
df
# Out:
#              eventid  Year  Month  Day  extended  country   Country Name  \
# 5       197001010002  1970      1    1         0      217  United States
# 6       197001020001  1970      1    2         0      218        Uruguay
# 7       197001020002  1970      1    2         0      217  United States
# 8       197001020003  1970      1    2         0      217  United States
# 9       197001030001  1970      1    3         0      217  United States
# ...              ...   ...    ...  ...       ...      ...            ...
# 181686  201712310022  2017     12   31         0      182        Somalia
# 181687  201712310029  2017     12   31         0      200          Syria
# 181688  201712310030  2017     12   31         0      160    Philippines
# 181689  201712310031  2017     12   31         0       92          India
# 181690  201712310032  2017     12   31         0      160    Philippines
#
#         region                 Region Name        provstate  ... nwoundus  \
# ...

# %%
df.isnull().sum()
# Out:
# eventid                 0
# Year                    0
# Month                   0
# Day                     0
# extended                0
# country                 0
# Country Name            0
# region                  0
# Region Name             0
# provstate              31
# city                  432
# latitude              952
# longitude             952
# specificity             6
# vicinity                0
# summary              5443
# crit1                   0
# crit2                   0
# crit3                   0
# doubtterr               1
# multiple                1
# success                 0
# suicide                 0
# attacktype1             0
# attacktype1_txt         0
# targtype1               0
# targtype1_txt           0
# targsubtype1         7051
# targsubtype1_txt     7051
# corp1               11573
# target1               194
# natlty1              1120
# natlty1_txt          1120
# gname                   0
# guncertain1           380
# ...

# %%
df
# Out:
#              eventid  Year  Month  Day  extended  country   Country Name  \
# 5       197001010002  1970      1    1         0      217  United States
# 6       197001020001  1970      1    2         0      218        Uruguay
# 7       197001020002  1970      1    2         0      217  United States
# 8       197001020003  1970      1    2         0      217  United States
# 9       197001030001  1970      1    3         0      217  United States
# ...              ...   ...    ...  ...       ...      ...            ...
# 181686  201712310022  2017     12   31         0      182        Somalia
# 181687  201712310029  2017     12   31         0      200          Syria
# 181688  201712310030  2017     12   31         0      160    Philippines
# 181689  201712310031  2017     12   31         0       92          India
# 181690  201712310032  2017     12   31         0      160    Philippines
#
#         region                 Region Name        provstate  ... nwoundus  \
# ...

# %%
df.isnull().sum()
# Out:
# eventid                 0
# Year                    0
# Month                   0
# Day                     0
# extended                0
# country                 0
# Country Name            0
# region                  0
# Region Name             0
# provstate              31
# city                  432
# latitude              952
# longitude             952
# specificity             6
# vicinity                0
# summary              5443
# crit1                   0
# crit2                   0
# crit3                   0
# doubtterr               1
# multiple                1
# success                 0
# suicide                 0
# attacktype1             0
# attacktype1_txt         0
# targtype1               0
# targtype1_txt           0
# targsubtype1         7051
# targsubtype1_txt     7051
# corp1               11573
# target1               194
# natlty1              1120
# natlty1_txt          1120
# gname                   0
# guncertain1           380
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120915 entries, 5 to 181690
# Data columns (total 58 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   eventid           120915 non-null  int64
#  1   Year              120915 non-null  int64
#  2   Month             120915 non-null  int64
#  3   Day               120915 non-null  int64
#  4   extended          120915 non-null  int64
#  5   country           120915 non-null  int64
#  6   Country Name      120915 non-null  object
#  7   region            120915 non-null  int64
#  8   Region Name       120915 non-null  object
#  9   provstate         120884 non-null  object
#  10  city              120483 non-null  object
#  11  latitude          119963 non-null  float64
#  12  longitude         119963 non-null  float64
#  13  specificity       120909 non-null  float64
#  14  vicinity          120915 non-null  int64
#  15  summary           115472 non-null  object
# ...

# %%
df=df.dropna(thresh=10 , axis =1)
df
# Out:
#              eventid  Year  Month  Day  extended  country   Country Name  \
# 5       197001010002  1970      1    1         0      217  United States
# 6       197001020001  1970      1    2         0      218        Uruguay
# 7       197001020002  1970      1    2         0      217  United States
# 8       197001020003  1970      1    2         0      217  United States
# 9       197001030001  1970      1    3         0      217  United States
# ...              ...   ...    ...  ...       ...      ...            ...
# 181686  201712310022  2017     12   31         0      182        Somalia
# 181687  201712310029  2017     12   31         0      200          Syria
# 181688  201712310030  2017     12   31         0      160    Philippines
# 181689  201712310031  2017     12   31         0       92          India
# 181690  201712310032  2017     12   31         0      160    Philippines
#
#         region                 Region Name        provstate  ... nwoundus  \
# ...

# %%
df.isnull().sum()
# Out:
# eventid                 0
# Year                    0
# Month                   0
# Day                     0
# extended                0
# country                 0
# Country Name            0
# region                  0
# Region Name             0
# provstate              31
# city                  432
# latitude              952
# longitude             952
# specificity             6
# vicinity                0
# summary              5443
# crit1                   0
# crit2                   0
# crit3                   0
# doubtterr               1
# multiple                1
# success                 0
# suicide                 0
# attacktype1             0
# attacktype1_txt         0
# targtype1               0
# targtype1_txt           0
# targsubtype1         7051
# targsubtype1_txt     7051
# corp1               11573
# target1               194
# natlty1              1120
# natlty1_txt          1120
# gname                   0
# guncertain1           380
# ...

# %%
df.columns.unique()
# Out:
# Index(['eventid', 'Year', 'Month', 'Day', 'extended', 'country',
#        'Country Name', 'region', 'Region Name', 'provstate', 'city',
#        'latitude', 'longitude', 'specificity', 'vicinity', 'summary', 'crit1',
#        'crit2', 'crit3', 'doubtterr', 'multiple', 'success', 'suicide',
#        'attacktype1', 'attacktype1_txt', 'targtype1', 'targtype1_txt',
#        'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1', 'natlty1',
#        'natlty1_txt', 'gname', 'guncertain1', 'individual', 'nperps',
#        'nperpcap', 'claimed', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'ishostkid', 'scite1',
#        'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY'],
#       dtype='object')

# %%
df['Country Name'].value_counts()
# Out:
# Iraq             24489
# Pakistan         12755
# Afghanistan      12624
# India             9313
# Philippines       5228
#                  ...
# Benin                1
# St. Lucia            1
# International        1
# Singapore            1
# Vatican City         1
# Name: Country Name, Length: 186, dtype: int64

# %%
df['Country Name'].value_counts()[0:10]
# Out:
# Iraq           24489
# Pakistan       12755
# Afghanistan    12624
# India           9313
# Philippines     5228
# Somalia         3994
# Nigeria         3846
# Thailand        3654
# Yemen           3266
# Colombia        2787
# Name: Country Name, dtype: int64

# %%
df['Year'].value_counts()
# Out:
# 2014    16899
# 2015    14961
# 2016    13582
# 2013    12036
# 2017    10899
# 2012     8522
# 2011     5076
# 2010     4826
# 2008     4798
# 2009     4710
# 2007     3235
# 2006     2754
# 2005     2013
# 2001     1904
# 2000     1811
# 1999     1391
# 2002     1332
# 2003     1278
# 2004     1164
# 1998      904
# 1989      561
# 1992      487
# 1988      456
# 1970      412
# 1990      384
# 1991      363
# 1987      361
# 1994      307
# 1986      304
# 1997      290
# 1984      246
# 1979      232
# 1983      211
# 1981      206
# 1978      204
# 1980      204
# 1996      202
# 1982      197
# 1985      193
# 1995      189
# 1977      184
# 1971      156
# 1972      141
# 1974      100
# 1975       97
# 1976       76
# 1973       57
# Name: Year, dtype: int64

# %%
df['Country Name'].value_counts()[0:10]
list(df["Country Name"].value_counts()[0:10].keys())
plt.figure(figsize=(12,15))
sns.barplot(list(df["Country Name"].value_counts()[0:10].keys()),df['Country Name'].value_counts()[0:10])
plt.xlabel('Country Names')
plt.ylabel('Numbers of Terrorist Attacks')
plt.show()

# %%
df['Year'].value_counts()[0:10]
# Out:
# 2014    16899
# 2015    14961
# 2016    13582
# 2013    12036
# 2017    10899
# 2012     8522
# 2011     5076
# 2010     4826
# 2008     4798
# 2009     4710
# Name: Year, dtype: int64

# %%
plt.figure(figsize=(12,10))
sns.histplot(df['Year'])
plt.xlabel('Years')
plt.ylabel('Numbers of Terrorist Attacks per year')
plt.show()

# %%
plt.subplots(figsize=(15,5))
sns.countplot('Region Name',data=df,edgecolor=sns.color_palette('dark',7),order=df['Region Name'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Number Of Terrorist Activities By Region')
plt.xlabel('Region Names')
plt.ylabel('Numbers of Terrorist Activity ')
plt.show()

# %%
# Attack type
plt.subplots(figsize=(15,6))
sns.countplot('attacktype1_txt',data=df,order=df['attacktype1_txt'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Attacking Types with Different Technique')
plt.xlabel('Attack Types')
plt.ylabel('Number of Times Terrorist Attacks')
plt.show()

# %%
#Target Types
plt.subplots(figsize=(15,6))
sns.countplot(df['targtype1_txt'],order=df['targtype1_txt'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Target Types')
plt.xlabel('Target Types')
plt.ylabel('Number  of Times Terrorist Attacks on Targets')
plt.show()

# %%
df[df['Country Name']=='India']['city'].value_counts()[0:10]
# Out:
# Imphal              406
# Srinagar            319
# Unknown             203
# Sopore               85
# Guwahati             68
# New Delhi            57
# Latehar district     55
# Anantnag             54
# Bijapur district     51
# Sukma district       49
# Name: city, dtype: int64

# %%
list(df[df['Country Name']=='India']['city'].value_counts()[0:10].keys())
# Out:
# ['Imphal',
#  'Srinagar',
#  'Unknown',
#  'Sopore',
#  'Guwahati',
#  'New Delhi',
#  'Latehar district',
#  'Anantnag',
#  'Bijapur district',
#  'Sukma district']

# %%
plt.figure(figsize=(12,15))
sns.barplot(list(df[df['Country Name']=='India']['city'].value_counts()[0:10].keys()),df[df['Country Name']=='India']['city'].value_counts()[0:10])
plt.show
# Out:
# <function matplotlib.pyplot.show>
